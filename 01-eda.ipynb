# %% [markdown]
# # __EDA__

# %%
from src.config import *

import os

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_results_df = pd.read_pickle(os.path.join(INTERIM_PATH, "all_results.pkl"))

# %%
all_results_df
# Out:
#      Rnk                  Name  d.o.b.     Bwt  IPF GL C  Squat 1  Squat 2  \
# 0      1           Guo Zhi Hao    2000   82.44    0.1389    242.5    255.0
# 1      1           Kelly Lewis    2000  119.13    0.1166    285.0    300.0
# 2      2        Okolo Chinedum    2001   82.48    0.1389    235.0    250.0
# 3      2              Wu Jason    2000   92.16    0.1314    277.5    295.5
# 4      3       Wilson Alasdair    2001  117.70    0.1172    300.0    320.5
# ..   ...                   ...     ...     ...       ...      ...      ...
# 691    6         Ringoot Steve    1989  142.20    0.1083    310.0      NaN
# 692    7  Stubberfield Jackson    1995  150.40    0.1060      NaN    317.5
# 693    8       Simonsen Martin    1999  176.90    0.1001    310.0    327.5
# 694    9        Juszczyk Jacek    1994  134.00    0.1109    305.0    320.0
# 695   10           Gecas Tadas    1977  145.00    0.1075    305.0      NaN
#
# ...

# %%
all_results_df.describe()
# Out:
#             Rnk       d.o.b.         Bwt    IPF GL C     Squat 1     Squat 2  \
# count     696.0   696.000000  696.000000  696.000000  634.000000  578.000000
# mean   9.576149  1994.285920   90.195862    0.136495  225.845426  238.229239
# std    7.130436    12.980567   23.076223    0.016579   50.404444   51.872968
# min         1.0  1958.000000   50.850000    0.097000   25.000000   75.000000
# 25%         4.0  1989.000000   73.375000    0.123900  190.000000  200.000000
# 50%         8.0  2000.000000   90.650000    0.132500  225.000000  237.500000
# 75%        14.0  2003.000000  104.127500    0.147425  260.000000  272.500000
# max        35.0  2008.000000  195.550000    0.179200  425.000000  455.000000
#
#           Squat 3  Bench Press 1  Bench Press 2  Bench Press 3  Deadlift 1  \
# count  430.000000     661.000000     587.000000     441.000000  656.000000
# mean   247.308140     146.609682     153.337308     158.842426  250.468750
# ...

# %% [markdown]
# ### __1. Посмотрим на распределение целевой переменной__

# %%
sns.displot(
    data=all_results_df,
    x='Best Bench'
)

# %%
sns.boxplot(
    data=all_results_df,
    x='Best Bench',
    showmeans=True,
    meanline=True
)
# Out:
# <Axes: xlabel='Best Bench'>

# %%
mean_bench = all_results_df['Best Bench'].mean()
median_bench = all_results_df['Best Bench'].median()

print(mean_bench, median_bench)
# Out:
# 156.08550287356323 156.25

# %% [markdown]
# ## __2. Изучение признаков__

# %% [markdown]
# __Выбросы:__

# %%
sns.boxplot(
    data=all_results_df,
    x='Age'
)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(
    data=all_results_df,
    x='Bwt'
)
# Out:
# <Axes: xlabel='Bwt'>

# %%
sns.boxplot(
    data=all_results_df,
    x='Best Squat'
)
# Out:
# <Axes: xlabel='Best Squat'>

# %%
sns.boxplot(
    data=all_results_df,
    x='Best Deadlift'
)
# Out:
# <Axes: xlabel='Best Deadlift'>

# %%
all_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rnk            696 non-null    Int64
#  1   Name           696 non-null    object
#  2   d.o.b.         696 non-null    int64
#  3   Bwt            696 non-null    float64
#  4   IPF GL C       696 non-null    float64
#  5   Squat 1        634 non-null    float64
#  6   Squat 2        578 non-null    float64
#  7   Squat 3        430 non-null    float64
#  8   Bench Press 1  661 non-null    float64
#  9   Bench Press 2  587 non-null    float64
#  10  Bench Press 3  441 non-null    float64
#  11  Deadlift 1     656 non-null    float64
#  12  Deadlift 2     589 non-null    float64
#  13  Deadlift 3     299 non-null    float64
#  14  Total          696 non-null    float64
#  15  IPF GL         696 non-null    float64
#  16  Pts            696 non-null    Int64
# ...

# %% [markdown]
# __Взаимное распределение__

# %%
features = ['Age', 'Bwt', 'Best Squat', 'Best Deadlift']
g = sns.PairGrid(data=all_results_df[features], corner=True)

g = g.map_diag(sns.histplot)
g = g.map_lower(sns.scatterplot)

# %%
sns.jointplot(
    data=all_results_df,
    x='Best Squat',
    y='Best Deadlift',
    kind='reg'
)

# %%
sns.jointplot(
    data=all_results_df,
    x='Bwt',
    y='Best Squat',
    kind='reg'
)

# %%
sns.jointplot(
    data=all_results_df,
    x='Bwt',
    y='Best Deadlift',
    kind='reg'
)

# %% [markdown]
# __Корреляции__

# %%
all_results_df[features].corr()
# Out:
#                     Age       Bwt  Best Squat  Best Deadlift
# Age            1.000000  0.093063   -0.194126      -0.216027
# Bwt            0.093063  1.000000    0.651214       0.502176
# Best Squat    -0.194126  0.651214    1.000000       0.844370
# Best Deadlift -0.216027  0.502176    0.844370       1.000000

# %%
sns.heatmap(
    data=all_results_df[features].corr(),
    annot=True,
    cmap="coolwarm"
)
# Out:
# <Axes: >

# %% [markdown]
# ## __3. Влияние признаков на целевую переменную__

# %%
sns.jointplot(
    data=all_results_df,
    x='Best Squat',
    y='Best Bench',
    kind='reg'
)

# %%
sns.jointplot(
    data=all_results_df,
    x='Best Deadlift',
    y='Best Bench',
    kind='reg'
)

# %%
sns.jointplot(
    data=all_results_df,
    x='Age',
    y='Best Bench',
    kind='reg'
)

# %%
sns.jointplot(
    data=all_results_df,
    x='Bwt',
    y='Best Bench',
    kind='reg'
)
